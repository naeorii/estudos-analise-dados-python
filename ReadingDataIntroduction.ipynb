# %% [markdown]
# <a href="https://colab.research.google.com/github/naeorii/estudos-analise-dados-python/blob/main/ReadingDataIntroduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Reading CSV and TXT files**
#
# Rather than creating `Series` or `DataFrames` strutures from scratch, or even from Python core sequences or `ndarrays`, the most typical use of **pandas** on the loading of information from  files or sources of information for further exploration, transformation and analysis.

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ##**Reading data with Python**

# %% [markdown]
# As we saw on previous courses we can read data simply using Python.
#
# When you want to work with a file, the first thing to do is to open it. This is done by invoking the `open()` built-in function.
#
# `open()` has a single required argument that is the path to the file and has a single return, the file object.
#
# The `with` statement automatically takes care of closing the file once it leaves the `with` block, even in cases of error.

# %%
with open("btc-market-price.csv", "r") as fp:
  print(fp)
# Out:
# <_io.TextIOWrapper name='btc-market-price.csv' mode='r' encoding='utf-8'>

# %% [markdown]
# Once the file is opened, we can read its content as it follows:

# %%
with open("btc-market-price.csv", "r") as fp:
  for index, line in enumerate(fp.readlines()):
    #read just th efirst 10 lines
    if (index <10):
      print(index, line)
# Out:
# 0 2017-04-02 00:00:00,1099.169125
#
# 1 2017-04-03 00:00:00,1141.813
#
# 2 2017-04-04 00:00:00,1141.6003625
#
# 3 2017-04-05 00:00:00,1133.0793142857142
#
# 4 2017-04-06 00:00:00,1196.3079375
#
# 5 2017-04-07 00:00:00,1190.45425
#
# 6 2017-04-08 00:00:00,1181.1498375
#
# 7 2017-04-09 00:00:00,1208.8005
#
# 8 2017-04-10 00:00:00,1207.744875
#
# 9 2017-04-11 00:00:00,1226.6170375

# %% [markdown]
# Splitting the values by the correct separator:

# %%
with open("btc-market-price.csv", "r") as fp:
  for index, line in enumerate(fp.readlines()):
    if index < 10:
      timestamp, price = line.split(",")
      print(f"{timestamp}: ${price}")
# Out:
# 2017-04-02 00:00:00: $1099.169125
#
# 2017-04-03 00:00:00: $1141.813
#
# 2017-04-04 00:00:00: $1141.6003625
#
# 2017-04-05 00:00:00: $1133.0793142857142
#
# 2017-04-06 00:00:00: $1196.3079375
#
# 2017-04-07 00:00:00: $1190.45425
#
# 2017-04-08 00:00:00: $1181.1498375
#
# 2017-04-09 00:00:00: $1208.8005
#
# 2017-04-10 00:00:00: $1207.744875
#
# 2017-04-11 00:00:00: $1226.6170375

# %% [markdown]
# But what happens if the separator is unknown like in the file exam_review.csv

# %%
# !head exam_review.csv
# Out:
# first_name>last_name>age>math_score>french_score
# Ray>Morley>18>"68,000">"75,000"
# Melvin>Scott>24>77>83
# Amirah>Haley>22>92>67
#
# Gerard>Mills>19>"78,000">72
# Amy>Grimes>23>91>81

# %% [markdown]
# The separator is the > sign

# %% [markdown]
# ###The CSV module

# %%
import csv

# %%
from IPython.core.magics.execution import math
with open("exam_review.csv", "r") as fp:
  reader = csv.reader(fp, delimiter=">")
  next(reader) #skipping header
  for index, values in enumerate(reader):
    if index < 10:
      if not values:
        continue #skip line
      fname, lname, age, math, french = values
      print(f"Name: {fname} {lname} (age {age}) got {math} in Math and {french} in French.")
# Out:
# Name: Ray Morley (age 18) got 68,000 in Math and 75,000 in French.
# Name: Melvin Scott (age 24) got 77 in Math and 83 in French.
# Name: Amirah Haley (age 22) got 92 in Math and 67 in French.
# Name: Gerard Mills (age 19) got 78,000 in Math and 72 in French.
# Name: Amy Grimes (age 23) got 91 in Math and 81 in French.
