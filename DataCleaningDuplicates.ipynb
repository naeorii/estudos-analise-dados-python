# %% [markdown]
# <a href="https://colab.research.google.com/github/naeorii/estudos-analise-dados-python/blob/main/DataCleaningDuplicates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##**Duplicates**

# %% [markdown]
# Checking duplicates is extremely simple. It'll behave differently between Series and DataFrames. Let's start with Series.As an example, let's say we're throwing a fancy party and we're inviting Ambassadors from Europe. But you can only invite one ambassador per country. This is our original list, and as you can see, both UK and Germany have duplicated ambassadors:

# %%
ambassadors = pd.Series([
    'France',
    'United Kingdom',
    'United Kingdom',
    'Italy',
    'Germany',
    'Germany',
    'Germany',
], index=[
    'Gerard Araud',
    'Kim Darroch',
    'Peter Westmacott',
    'Armando Varricchio',
    'Peter Wittig',
    'Peter Ammon',
    'Klaus Scharioth'
])

# %%
ambassadors
# Out:
# Gerard Araud                  France
# Kim Darroch           United Kingdom
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# Peter Ammon                  Germany
# Klaus Scharioth              Germany
# dtype: object

# %% [markdown]
# The two most important methods to deal with duplicates are `duplicated` (that will tell you which values are duplicates) and `drop_duplicates` (which will jjust get rid of duplicates):

# %%
ambassadors.duplicated() #quais valores são duplicados
# Out:
# Gerard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# By default it'll consider the first occurence of the value as not-duplicate. You can change this behavior with the `keep `parameter:

# %%
ambassadors.duplicated(keep='last')  #the first ambassadors are considered duplicates
# Out:
# Gerard Araud          False
# Kim Darroch            True
# Peter Westmacott      False
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth       False
# dtype: bool

# %% [markdown]
# You can also choose to mark all of them as duplicates with `keep=False`:

# %%
ambassadors.duplicated(keep=False)
# Out:
# Gerard Araud          False
# Kim Darroch            True
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# A similar method is` drop_duplicates`, which just excludes the duplicated values and also accepts the `keep `parameter:

# %%
ambassadors.drop_duplicates()
# Out:
# Gerard Araud                  France
# Kim Darroch           United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep='last')
# Out:
# Gerard Araud                  France
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Klaus Scharioth              Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep=False)
# Out:
# Gerard Araud          France
# Armando Varricchio     Italy
# dtype: object

# %% [markdown]
# ##**Duplicates in DataFrames**

# %% [markdown]
# Conceptually speaking, duplicates in DataFRame happen at 'row' level. Two rows with exaclty the same values are considered to be duplicates:

# %%
players = pd.DataFrame({
    'Name': [
        'Kobe Bryant',
        'LeBron James',
        'Kobe Bryant',
        'Carmelo Anthony',
        'Kobe Bryant',
    ],
    'Pos': [
        'SG',
        'SF',
        'SG',
        'SF',
        'SF'
    ]
})

# %%
players
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 2      Kobe Bryant  SG
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %% [markdown]
# Kobe is duplicated; but he appears with two different positions. What does `duplicated `say?

# %%
players.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# "Duplicated means wall the column values should be duplicates. We can customize this with the `subset `parameter:

# %%
players.duplicated(subset=['Name'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# And the same rules of `keep` still apply:

# %%
players.duplicated(subset=['Name'], keep='last')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# `drop_duplicates` takes the same parameters:

# %%
players.drop_duplicates()
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.drop_duplicates(subset=['Name'])
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF

# %%
players.drop_duplicates(subset=['Name'], keep='last')
# Out:
#               Name Pos
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %% [markdown]
# ---
